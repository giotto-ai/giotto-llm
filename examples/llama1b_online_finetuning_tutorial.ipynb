# %% [markdown]
# In this notebook we will show you how to use our library in order to run Train-Time fine-tuning for ARC-Challenge.

# %%
# %%capture
# Install the giotto-llm package
# !pip3 install giotto-llm
# Get Datasets
# !mkdir kaggle
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1ISFkhGIc-i6Djdp55WxCI2b-PUu3hgTS' -O kaggle/input.zip
# !unzip kaggle/input.zip -d kaggle/
# !rm -rf kaggle/input.zip
# !rm -rf kaggle/__MACOSX
# Get the pre-trained model
# !mkdir models
# !gsutil cp -r gs://public-models-and-datasets/models/merged_llama_v6/ models/

# %%
# Install dependencies.
# !pip install liger-kernel
# !pip install qwen_vl_utils
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu118
# !pip install trl
# !pip install bitsandbytes==0.44.0
# Out:
# Collecting liger-kernel
#   Downloading liger_kernel-0.4.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from liger-kernel) (2.4.1)
# Requirement already satisfied: triton>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from liger-kernel) (3.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.2->liger-kernel) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.2->liger-kernel) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.1.2->liger-kernel) (1.3.0)
# Downloading liger_kernel-0.4.2-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: liger-kernel
# Successfully installed liger-kernel-0.4.2
# Collecting qwen_vl_utils
#   Downloading qwen_vl_utils-0.0.8-py3-none-any.whl.metadata (3.6 kB)
# Collecting av (from qwen_vl_utils)
#   Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from qwen_vl_utils) (24.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from qwen_vl_utils) (11.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from qwen_vl_utils) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->qwen_vl_utils) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->qwen_vl_utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->qwen_vl_utils) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->qwen_vl_utils) (2024.8.30)
# Downloading qwen_vl_utils-0.0.8-py3-none-any.whl (5.9 kB)
# Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 58.4 MB/s eta 0:00:00
# Installing collected packages: av, qwen_vl_utils
# Successfully installed av-14.0.1 qwen_vl_utils-0.0.8
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.4.0
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.4.0%2Bcu118-cp310-cp310-linux_x86_64.whl (857.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.7/857.7 MB 1.5 MB/s eta 0:00:00
# Collecting torchvision==0.19.0
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.19.0%2Bcu118-cp310-cp310-linux_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 106.6 MB/s eta 0:00:00
# Collecting torchaudio==2.4.0
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.4.0%2Bcu118-cp310-cp310-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 64.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (2024.9.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 83.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 47.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 101.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==9.1.0.70 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB ? eta 0:00:00
# Collecting nvidia-cublas-cu11==11.11.3.6 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.3.0.86 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 13.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 6.9 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 6.0 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.20.5 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.20.5-py3-none-manylinux2014_x86_64.whl (142.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.8.86 (from torch==2.4.0)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0) (3.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.19.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.19.0) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu121
#     Uninstalling torchaudio-2.5.1+cu121:
#       Successfully uninstalled torchaudio-2.5.1+cu121
# Successfully installed nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.1.0.70 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.20.5 nvidia-nvtx-cu11-11.8.86 torch-2.4.0+cu118 torchaudio-2.4.0+cu118 torchvision-0.19.0+cu118
# Collecting trl
#   Downloading trl-0.12.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: accelerate>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from trl) (1.1.1)
# Requirement already satisfied: datasets>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from trl) (3.1.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: transformers<4.47.0 in /usr/local/lib/python3.10/dist-packages (from trl) (4.46.3)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (0.23.5)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (0.4.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (2.4.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.21.0->trl) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (3.11.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.47.0->trl) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<4.47.0->trl) (0.20.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2024.8.30)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.21.0->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.21.0->trl) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.21.0->trl) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate>=0.34.0->trl) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate>=0.34.0->trl) (1.3.0)
# Downloading trl-0.12.2-py3-none-any.whl (365 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: trl
# Successfully installed trl-0.12.2
# Collecting bitsandbytes==0.44.0
#   Using cached bitsandbytes-0.44.0-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.44.0) (2.4.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.44.0) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.44.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes==0.44.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes==0.44.0) (1.3.0)
# Using cached bitsandbytes-0.44.0-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.44.0

# %%
import giotto_llm
import os

# Choose of the pre-trained models
models = [
    "merged_llama_v7", # Llama 1B trained on V7 dataset. All 800-tasks were used for training.
    "merged_llama_v6",
    "merged_llama_1b_v5", # Llama 1B trained on V5 dataset. Only 400-train tasks were used for training.
]

# CHOOSE THE BASE MODEL
model_name = models[1]

ONLINE_FINETUNING_PARAMS = {
     # DATA
    "dataset_dir": "kaggle/input",
    "dataset_category": "evaluation", # The category of the dataset. Options: evaluation, full
    "start_index_tasks": 0, # The start index of the tasks to be used for online finetuning
    "end_index_tasks": 401,  # The end index of the tasks to be used for online finetuning

    # General parameters
    "model_name": f"models/{model_name}",
    "num_train_epochs": 30,
    "eval_steps": 31, # Number of steps for evaluation
    "save_total_limit": 1, # Number of checkpoints to save
    "learning_rate": 4e-4,
    "batch_size": 1,
    "gradient_accumulation_steps": 16,
    "quantization": "4bit-nf4", # options: 4bit-nf4, 8bit-nf4, 8bit-nf8
    "num_tasks_per_gpu_process": 1,

    # LORA parameters
    "lora_r": 1,
    "neftune_noise_alpha": 10.0,
    "lora_dropout": 0.2,

    # PROMPT
    "prompt_type": "prompt_solve_short",

    # OUTPUT
    "output_dir": f"results_{model_name}",

    # TIME LIMIT FOR TRAINING
    "timeout": 105 * 6 * 60, # 10.5 hours
}

# Setting online finetuning time limit.
os.environ["ONLINE_FINETUNING_TIME_LIMIT"] = str(ONLINE_FINETUNING_PARAMS["timeout"])
os.environ["WANDB_MODE"] = "disabled"

# %%
#### ----------------------------------------------------
####      ONLINE FINETUNING
#### ----------------------------------------------------

! python -m giotto_llm.online_fine_tuning.paralel_online_finetuning \
--dataset_dir {ONLINE_FINETUNING_PARAMS["dataset_dir"]} \
--dataset_category {ONLINE_FINETUNING_PARAMS["dataset_category"]} \
--model_id {ONLINE_FINETUNING_PARAMS["model_name"]} \
--wrapper CausalLM \
--batch_size {ONLINE_FINETUNING_PARAMS["batch_size"]} \
--gradient_accumulation_steps {ONLINE_FINETUNING_PARAMS["gradient_accumulation_steps"]} \
--quantization {ONLINE_FINETUNING_PARAMS["quantization"]} \
--neftune_noise_alpha {ONLINE_FINETUNING_PARAMS["neftune_noise_alpha"]} \
--num_train_epochs {ONLINE_FINETUNING_PARAMS["num_train_epochs"]} \
--learning_rate {ONLINE_FINETUNING_PARAMS["learning_rate"]} \
--lora_r {ONLINE_FINETUNING_PARAMS["lora_r"]}\
--save_total_limit {ONLINE_FINETUNING_PARAMS["save_total_limit"]} \
--eval_steps {ONLINE_FINETUNING_PARAMS["eval_steps"]} \
--num_tasks_per_gpu_process {ONLINE_FINETUNING_PARAMS["num_tasks_per_gpu_process"]} \
--prompt_type {ONLINE_FINETUNING_PARAMS["prompt_type"]} \
--output_dir {ONLINE_FINETUNING_PARAMS["output_dir"]} \
--lora_dropout {ONLINE_FINETUNING_PARAMS["lora_dropout"]} \
--start_index_tasks {ONLINE_FINETUNING_PARAMS["start_index_tasks"]} \
--end_index_tasks {ONLINE_FINETUNING_PARAMS["end_index_tasks"]}
# Out:
# 13:28:11 INFO:>>> Starting parallelized validation
# 13:28:11 INFO:>>> Saving submission.json files to results_merged_llama_v6/predictions
# 13:28:11 INFO:>>> Saving logs to results_merged_llama_v6/logs
# 13:28:11 INFO:------------------------------
# 13:28:11 INFO:>>> Found 1 GPUs
# 13:28:11 INFO:>>> Logging resource usage to results_merged_llama_v6/monitor.csv every 1.0 seconds...
# 13:28:11 INFO:>>> Found 400 tasks with arguments.dataset_dir='kaggle/input', arguments.dataset_category='evaluation'
# 13:28:11 INFO:>>> Dividing tasks into 400 batches, each with up to 1 tasks
# 13:28:11 INFO:>>> Going to run the following command as subprocess
# 13:28:11 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '0', '--end_index_tasks', '1', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 13:28:11 INFO:>>> Started subprocesses: {1: (<Popen: returncode: None args: ['python', '-m', 'giotto_llm.online_fine_tuni...>, 0, 0)}
# 13:31:31 INFO:>>> Task batch 0 successful, with tasks ['00576224']
# 13:31:31 INFO:>>> Going to run the following command as subprocess
# 13:31:31 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '1', '--end_index_tasks', '2', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 13:38:38 INFO:>>> Task batch 1 successful, with tasks ['009d5c81']
# 13:38:38 INFO:>>> Going to run the following command as subprocess
# 13:38:38 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '2', '--end_index_tasks', '3', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 13:45:13 INFO:>>> Task batch 2 successful, with tasks ['00dbd492']
# 13:45:13 INFO:>>> Going to run the following command as subprocess
# 13:45:13 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '3', '--end_index_tasks', '4', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 13:48:56 INFO:>>> Task batch 3 successful, with tasks ['03560426']
# 13:48:56 INFO:>>> Going to run the following command as subprocess
# 13:48:56 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '4', '--end_index_tasks', '5', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:01:08 INFO:>>> Task batch 4 successful, with tasks ['05a7bcf2']
# 14:01:08 INFO:>>> Going to run the following command as subprocess
# 14:01:08 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '5', '--end_index_tasks', '6', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:09:07 INFO:>>> Task batch 5 successful, with tasks ['0607ce86']
# 14:09:07 INFO:>>> Going to run the following command as subprocess
# 14:09:07 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '6', '--end_index_tasks', '7', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:12:12 INFO:>>> Task batch 6 successful, with tasks ['0692e18c']
# 14:12:12 INFO:>>> Going to run the following command as subprocess
# 14:12:12 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '7', '--end_index_tasks', '8', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:17:06 INFO:>>> Task batch 7 successful, with tasks ['070dd51e']
# 14:17:06 INFO:>>> Going to run the following command as subprocess
# 14:17:06 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '8', '--end_index_tasks', '9', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:21:03 INFO:>>> Task batch 8 successful, with tasks ['08573cc6']
# 14:21:03 INFO:>>> Going to run the following command as subprocess
# 14:21:03 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '9', '--end_index_tasks', '10', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:30:53 INFO:>>> Task batch 9 successful, with tasks ['0934a4d8']
# 14:30:53 INFO:>>> Going to run the following command as subprocess
# 14:30:53 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '10', '--end_index_tasks', '11', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:40:40 INFO:>>> Task batch 10 successful, with tasks ['09c534e7']
# 14:40:40 INFO:>>> Going to run the following command as subprocess
# 14:40:40 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '11', '--end_index_tasks', '12', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:47:08 INFO:>>> Task batch 11 successful, with tasks ['0a1d4ef5']
# 14:47:08 INFO:>>> Going to run the following command as subprocess
# 14:47:08 INFO:	- ['python', '-m', 'giotto_llm.online_fine_tuning', '--dataset_dir', 'kaggle/input', '--dataset_category', 'evaluation', '--start_index_tasks', '12', '--end_index_tasks', '13', '--gpu_index', '0', '--model_id', 'models/merged_llama_v6', '--wrapper', 'CausalLM', '--output_dir', 'results_merged_llama_v6', '--quantization', '4bit-nf4', '--transform_background_color', 'True', '--learning_rate', '0.0004', '--batch_size', '1', '--gradient_accumulation_steps', '16', '--num_train_epochs', '30', '--neftune_noise_alpha', '10.0', '--prompt_type', 'prompt_solve_short', '--eval_steps', '31', '--lora_dropout', '0.2', '--lora_alpha', '16', '--lora_r', '1', '--save_total_limit', '1']
# 14:51:02 INFO:>>> Main execution finished. Monitoring thread will stop.
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/giotto_llm/online_fine_tuning/paralel_online_finetuning.py", line 335, in <module>
#     main(arguments, logger=logger)
#   File "/usr/local/lib/python3.10/dist-packages/giotto_llm/online_fine_tuning/paralel_online_finetuning.py", line 186, in main
#     if pro.poll() is not None:  # Process finished
#   File "/usr/lib/python3.10/subprocess.py", line 1181, in poll
#     return self._internal_poll()
#   File "/usr/lib/python3.10/subprocess.py", line 1896, in _internal_poll
#     pid, sts = _waitpid(self.pid, _WNOHANG)
# KeyboardInterrupt
# ^C
